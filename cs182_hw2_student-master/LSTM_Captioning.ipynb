# %% [markdown]
# # Image Captioning with LSTMs
# In the previous exercise you implemented a vanilla RNN and applied it to image captioning. In this notebook you will implement the LSTM update rule and use it for image captioning.

# %%
# As usual, a bit of setup
from __future__ import print_function
import time, os, json
import numpy as np
import matplotlib.pyplot as plt
import pickle

from deeplearning.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from deeplearning.rnn_layers import *
from deeplearning.captioning_solver import CaptioningSolver
from deeplearning.classifiers.rnn import CaptioningRNN
from deeplearning.coco_utils import load_coco_data, sample_coco_minibatch, decode_captions
from deeplearning.image_utils import image_from_url

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# # Load MS-COCO data
# As in the previous notebook, we will use the Microsoft COCO dataset for captioning.

# %%
# Load COCO data from disk; this returns a dictionary
# We'll work with dimensionality-reduced features for this notebook, but feel
# free to experiment with the original features by changing the flag below.
data = load_coco_data(pca_features=True)

# Print out all the keys and values from the data dictionary
for k, v in data.items():
    if type(v) == np.ndarray:
        print(k, type(v), v.shape, v.dtype)
    else:
        print(k, type(v), len(v))
# Out:
# train_captions <class 'numpy.ndarray'> (400135, 17) int32
# train_image_idxs <class 'numpy.ndarray'> (400135,) int32
# val_captions <class 'numpy.ndarray'> (195954, 17) int32
# val_image_idxs <class 'numpy.ndarray'> (195954,) int32
# train_features <class 'numpy.ndarray'> (82783, 512) float32
# val_features <class 'numpy.ndarray'> (40504, 512) float32
# idx_to_word <class 'list'> 1004
# word_to_idx <class 'dict'> 1004
# train_urls <class 'numpy.ndarray'> (82783,) <U63
# val_urls <class 'numpy.ndarray'> (40504,) <U63

# %% [markdown]
# # LSTM
# If you read recent papers, you'll see that many people use a variant on the vanialla RNN called Long-Short Term Memory (LSTM) RNNs. Vanilla RNNs can be tough to train on long sequences due to vanishing and exploding gradiants caused by repeated matrix multiplication. LSTMs solve this problem by replacing the simple update rule of the vanilla RNN with a gating mechanism as follows.
#
# Similar to the vanilla RNN, at each timestep we receive an input $x_t\in\mathbb{R}^D$ and the previous hidden state $h_{t-1}\in\mathbb{R}^H$; the LSTM also maintains an $H$-dimensional *cell state*, so we also receive the previous cell state $c_{t-1}\in\mathbb{R}^H$. The learnable parameters of the LSTM are an *input-to-hidden* matrix $W_x\in\mathbb{R}^{4H\times D}$, a *hidden-to-hidden* matrix $W_h\in\mathbb{R}^{4H\times H}$ and a *bias vector* $b\in\mathbb{R}^{4H}$.
#
# At each timestep we first compute an *activation vector* $a\in\mathbb{R}^{4H}$ as $a=W_xx_t + W_hh_{t-1}+b$. We then divide this into four vectors $a_i,a_f,a_o,a_g\in\mathbb{R}^H$ where $a_i$ consists of the first $H$ elements of $a$, $a_f$ is the next $H$ elements of $a$, etc. We then compute the *input gate* $g\in\mathbb{R}^H$, *forget gate* $f\in\mathbb{R}^H$, *output gate* $o\in\mathbb{R}^H$ and *block input* $g\in\mathbb{R}^H$ as
#
# $$
# \begin{align*}
# i = \sigma(a_i) \hspace{2pc}
# f = \sigma(a_f) \hspace{2pc}
# o = \sigma(a_o) \hspace{2pc}
# g = \tanh(a_g)
# \end{align*}
# $$
#
# where $\sigma$ is the sigmoid function and $\tanh$ is the hyperbolic tangent, both applied elementwise.
#
# Finally we compute the next cell state $c_t$ and next hidden state $h_t$ as
#
# $$
# c_{t} = f\odot c_{t-1} + i\odot g \hspace{4pc}
# h_t = o\odot\tanh(c_t)
# $$
#
# where $\odot$ is the elementwise product of vectors.
#
# In the rest of the notebook we will implement the LSTM update rule and apply it to the image captioning task.
#
# In the code, we assume that data is stored in batches so that $X_t \in \mathbb{R}^{N\times D}$, and will work with *transposed* versions of the parameters: $W_x \in \mathbb{R}^{D \times 4H}$, $W_h \in \mathbb{R}^{H\times 4H}$ so that activations $A \in \mathbb{R}^{N\times 4H}$ can be computed efficiently as $A = X_t W_x + H_{t-1} W_h$

# %% [markdown]
# # LSTM: step forward
# Implement the forward pass for a single timestep of an LSTM in the `lstm_step_forward` function in the file `deeplearning/rnn_layers.py`. This should be similar to the `rnn_step_forward` function that you implemented above, but using the LSTM update rule instead.
#
# Once you are done, run the following to perform a simple test of your implementation. You should see errors around `1e-8` or less.

# %%
N, D, H = 3, 4, 5
x = np.linspace(-0.4, 1.2, num=N*D).reshape(N, D)
prev_h = np.linspace(-0.3, 0.7, num=N*H).reshape(N, H)
prev_c = np.linspace(-0.4, 0.9, num=N*H).reshape(N, H)
Wx = np.linspace(-2.1, 1.3, num=4*D*H).reshape(D, 4 * H)
Wh = np.linspace(-0.7, 2.2, num=4*H*H).reshape(H, 4 * H)
b = np.linspace(0.3, 0.7, num=4*H)

next_h, next_c, cache = lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)

expected_next_h = np.asarray([
    [ 0.24635157,  0.28610883,  0.32240467,  0.35525807,  0.38474904],
    [ 0.49223563,  0.55611431,  0.61507696,  0.66844003,  0.7159181 ],
    [ 0.56735664,  0.66310127,  0.74419266,  0.80889665,  0.858299  ]])
expected_next_c = np.asarray([
    [ 0.32986176,  0.39145139,  0.451556,    0.51014116,  0.56717407],
    [ 0.66382255,  0.76674007,  0.87195994,  0.97902709,  1.08751345],
    [ 0.74192008,  0.90592151,  1.07717006,  1.25120233,  1.42395676]])

print('next_h error: ', rel_error(expected_next_h, next_h))
print('next_c error: ', rel_error(expected_next_c, next_c))
# Out:
# next_h error:  5.7054130404539434e-09
# next_c error:  5.8143123088804145e-09

# %% [markdown]
# # LSTM: step backward
# Implement the backward pass for a single LSTM timestep in the function `lstm_step_backward` in the file `deeplearning/rnn_layers.py`. Once you are done, run the following to perform numeric gradient checking on your implementation. You should see errors around `1e-6` or less.

# %%
np.random.seed(231)

N, D, H = 4, 5, 6
x = np.random.randn(N, D)
prev_h = np.random.randn(N, H)
prev_c = np.random.randn(N, H)
Wx = np.random.randn(D, 4 * H)
Wh = np.random.randn(H, 4 * H)
b = np.random.randn(4 * H)

next_h, next_c, cache = lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)

dnext_h = np.random.randn(*next_h.shape)
dnext_c = np.random.randn(*next_c.shape)

fx_h = lambda x: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fh_h = lambda h: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fc_h = lambda c: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fWx_h = lambda Wx: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fWh_h = lambda Wh: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fb_h = lambda b: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]

fx_c = lambda x: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fh_c = lambda h: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fc_c = lambda c: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fWx_c = lambda Wx: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fWh_c = lambda Wh: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fb_c = lambda b: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]

num_grad = eval_numerical_gradient_array

dx_num = num_grad(fx_h, x, dnext_h) + num_grad(fx_c, x, dnext_c)
dh_num = num_grad(fh_h, prev_h, dnext_h) + num_grad(fh_c, prev_h, dnext_c)
dc_num = num_grad(fc_h, prev_c, dnext_h) + num_grad(fc_c, prev_c, dnext_c)
dWx_num = num_grad(fWx_h, Wx, dnext_h) + num_grad(fWx_c, Wx, dnext_c)
dWh_num = num_grad(fWh_h, Wh, dnext_h) + num_grad(fWh_c, Wh, dnext_c)
db_num = num_grad(fb_h, b, dnext_h) + num_grad(fb_c, b, dnext_c)

dx, dh, dc, dWx, dWh, db = lstm_step_backward(dnext_h, dnext_c, cache)

print('dx error: ', rel_error(dx_num, dx))
print('dh error: ', rel_error(dh_num, dh))
print('dc error: ', rel_error(dc_num, dc))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  6.33535571978729e-10
# dh error:  3.3963782865809294e-10
# dc error:  1.5221771913099803e-10
# dWx error:  2.1010960934639614e-09
# dWh error:  9.712296180612259e-08
# db error:  2.4915214652298706e-10

# %% [markdown]
# # LSTM: forward
# In the function `lstm_forward` in the file `deeplearning/rnn_layers.py`, implement the `lstm_forward` function to run an LSTM forward on an entire timeseries of data.
#
# When you are done, run the following to check your implementation. You should see an error around `1e-7`.

# %%
N, D, H, T = 2, 5, 4, 3
x = np.linspace(-0.4, 0.6, num=N*T*D).reshape(N, T, D)
h0 = np.linspace(-0.4, 0.8, num=N*H).reshape(N, H)
Wx = np.linspace(-0.2, 0.9, num=4*D*H).reshape(D, 4 * H)
Wh = np.linspace(-0.3, 0.6, num=4*H*H).reshape(H, 4 * H)
b = np.linspace(0.2, 0.7, num=4*H)

h, cache = lstm_forward(x, h0, Wx, Wh, b)

expected_h = np.asarray([
 [[ 0.01764008,  0.01823233,  0.01882671,  0.0194232 ],
  [ 0.11287491,  0.12146228,  0.13018446,  0.13902939],
  [ 0.31358768,  0.33338627,  0.35304453,  0.37250975]],
 [[ 0.45767879,  0.4761092,   0.4936887,   0.51041945],
  [ 0.6704845,   0.69350089,  0.71486014,  0.7346449 ],
  [ 0.81733511,  0.83677871,  0.85403753,  0.86935314]]])

print('h error: ', rel_error(expected_h, h))
# Out:
# h error:  8.610537452106624e-08

# %% [markdown]
# # LSTM: backward
# Implement the backward pass for an LSTM over an entire timeseries of data in the function `lstm_backward` in the file `deeplearning/rnn_layers.py`. When you are done, run the following to perform numeric gradient checking on your implementation. You should see errors around `1e-6` or less.

# %%
from deeplearning.rnn_layers import lstm_forward, lstm_backward
np.random.seed(231)

N, D, T, H = 2, 3, 10, 6

x = np.random.randn(N, T, D)
h0 = np.random.randn(N, H)
Wx = np.random.randn(D, 4 * H)
Wh = np.random.randn(H, 4 * H)
b = np.random.randn(4 * H)

out, cache = lstm_forward(x, h0, Wx, Wh, b)

dout = np.random.randn(*out.shape)

dx, dh0, dWx, dWh, db = lstm_backward(dout, cache)

fx = lambda x: lstm_forward(x, h0, Wx, Wh, b)[0]
fh0 = lambda h0: lstm_forward(x, h0, Wx, Wh, b)[0]
fWx = lambda Wx: lstm_forward(x, h0, Wx, Wh, b)[0]
fWh = lambda Wh: lstm_forward(x, h0, Wx, Wh, b)[0]
fb = lambda b: lstm_forward(x, h0, Wx, Wh, b)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
dh0_num = eval_numerical_gradient_array(fh0, h0, dout)
dWx_num = eval_numerical_gradient_array(fWx, Wx, dout)
dWh_num = eval_numerical_gradient_array(fWh, Wh, dout)
db_num = eval_numerical_gradient_array(fb, b, dout)

print('dx error: ', rel_error(dx_num, dx))
print('dh0 error: ', rel_error(dh0_num, dh0))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  5.5899935079979534e-09
# dh0 error:  1.034134248343058e-08
# dWx error:  2.370328212185088e-09
# dWh error:  2.3305783878166446e-06
# db error:  1.6786130660417645e-09

# %% [markdown]
# # LSTM captioning model
#
# Now that you have implemented an LSTM, update the implementation of the `loss` method of the `CaptioningRNN` class in the file `deeplearning/classifiers/rnn.py` to handle the case where `self.cell_type` is `lstm`. This should require adding less than 10 lines of code.
#
# Once you have done so, run the following to check your implementation. You should see a difference of less than `1e-10`.

# %%
N, D, W, H = 10, 20, 30, 40
word_to_idx = {'<NULL>': 0, 'cat': 2, 'dog': 3}
V = len(word_to_idx)
T = 13

model = CaptioningRNN(word_to_idx,
          input_dim=D,
          wordvec_dim=W,
          hidden_dim=H,
          cell_type='lstm',
          dtype=np.float64)

# Set all model parameters to fixed values
for k, v in model.params.items():
  model.params[k] = np.linspace(-1.4, 1.3, num=v.size).reshape(*v.shape)

features = np.linspace(-0.5, 1.7, num=N*D).reshape(N, D)
captions = (np.arange(N * T) % V).reshape(N, T)

loss, grads = model.loss(features, captions)
expected_loss = 9.82445935443

print('loss: ', loss)
print('expected loss: ', expected_loss)
print('difference: ', abs(loss - expected_loss))
# Out:
# loss:  9.824459354432266
# expected loss:  9.82445935443
# difference:  2.2666313270747196e-12

# %% [markdown]
# # Overfit LSTM captioning model
# Run the following to overfit an LSTM captioning model on the same small dataset as we used for the RNN previously. You should see losses less than 0.5.

# %%
np.random.seed(231)

small_data = load_coco_data(max_train=50)

small_lstm_model = CaptioningRNN(
          cell_type='lstm',
          word_to_idx=data['word_to_idx'],
          input_dim=data['train_features'].shape[1],
          hidden_dim=512,
          wordvec_dim=256,
          dtype=np.float32,
        )

small_lstm_solver = CaptioningSolver(small_lstm_model, small_data,
           update_rule='adam',
           num_epochs=50,
           batch_size=25,
           optim_config={
             'learning_rate': 5e-3,
           },
           lr_decay=0.995,
           verbose=True, print_every=10,
         )

small_lstm_solver.train()

# Plot the training losses
plt.plot(small_lstm_solver.loss_history)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training loss history')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2070/3572030895.py in <module>
#      23          )
#      24
# ---> 25 small_lstm_solver.train()
#      26
#      27 # Plot the training losses
#
# TypeError: train() missing 1 required positional argument: 'eval'

# %% [markdown]
# # LSTM test-time sampling
# Modify the `sample` method of the `CaptioningRNN` class to handle the case where `self.cell_type` is `lstm`. This should take fewer than 10 lines of code.
#
# When you are done run the following to sample from your overfit LSTM model on some training and validation set samples.

# %%
for split in ['train', 'val']:
    minibatch = sample_coco_minibatch(small_data, split=split, batch_size=2)
    gt_captions, features, urls = minibatch
    gt_captions = decode_captions(gt_captions, data['idx_to_word'])

    sample_captions = small_lstm_model.sample(features)
    sample_captions = decode_captions(sample_captions, data['idx_to_word'])

    for gt_caption, sample_caption, url in zip(gt_captions, sample_captions, urls):
        image = image_from_url(url)
        if image is None:
            continue
        plt.imshow(image_from_url(url))
        plt.title('%s\n%s\nGT:%s' % (split, sample_caption, gt_caption))
        plt.axis('off')
        plt.show()

# %% [markdown]
# # Extra Credit: Train a good captioning model!
# Using the pieces you have implemented in this and the previous notebook, try to train a captioning model that gives decent qualitative results (better than the random garbage you saw with the overfit models) when sampling on the validation set. You can subsample the training set if you want; we just want to see samples on the validation set that are better than random.
#
# In addition to qualitatively evaluating your model by inspecting its results, you can also quantitatively evaluate your model using the BLEU unigram precision metric. We'll give you a small amount of extra credit if you can train a model that achieves a BLEU unigram score of >0.3. BLEU scores range from 0 to 1; the closer to 1, the better. Here's a reference to the [paper](http://www.aclweb.org/anthology/P02-1040.pdf) that introduces BLEU if you're interested in learning more about how it works.
#
# Feel free to use PyTorch or TensorFlow for this section if you'd like to train faster on a GPU... though you can definitely get above 0.3 using your Numpy code. We're providing you the evaluation code that is compatible with the Numpy model as defined above... you should be able to adapt it for TensorFlow/PyTorch if you go that route.
#
# **Note that you must call save_model_prediction in order to save your model prediction to receive extra credit!**

# %%
import nltk

def BLEU_score(gt_caption, sample_caption):
    """
    gt_caption: string, ground-truth caption
    sample_caption: string, your model's predicted caption
    Returns unigram BLEU score.
    """
    reference = [x for x in gt_caption.split(' ') 
                 if ('<END>' not in x and '<START>' not in x and '<UNK>' not in x)]
    hypothesis = [x for x in sample_caption.split(' ') 
                  if ('<END>' not in x and '<START>' not in x and '<UNK>' not in x)]
    BLEUscore = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis, weights = [1])
    return BLEUscore

def evaluate_model(model):
    """
    model: CaptioningRNN model
    Prints unigram BLEU score averaged over 1000 training and val examples.
    """
    BLEUscores = {}
    for split in ['train', 'val']:
        minibatch = sample_coco_minibatch(data, split=split, batch_size=1000)
        gt_captions, features, urls = minibatch
        gt_captions = decode_captions(gt_captions, data['idx_to_word'])

        sample_captions = model.sample(features)
        sample_captions = decode_captions(sample_captions, data['idx_to_word'])

        total_score = 0.0
        for gt_caption, sample_caption, url in zip(gt_captions, sample_captions, urls):
            total_score += BLEU_score(gt_caption, sample_caption)

        BLEUscores[split] = total_score / len(sample_captions)

    for split in BLEUscores:
        print('Average BLEU score for %s: %f' % (split, BLEUscores[split]))
    if BLEUscores['train'] > 0.3 and BLEUscores['val'] > 0.3:
        save_data = {
        'sample_captions': sample_captions,
        'gt_captions': gt_captions
        }
        with open('captioning_extra_credit.pkl', 'wb') as fout:
            pickle.dump(save_data, fout)
    
        
def save_model_prediction(model):
    """
    Save the model prediction for autograding
    """
    minibatch = sample_coco_minibatch(data, split='val', batch_size=1000)
    gt_captions, features, urls = minibatch
    gt_captions = decode_captions(gt_captions, data['idx_to_word'])
    sample_captions = model.sample(features)
    sample_captions = decode_captions(sample_captions, data['idx_to_word'])
    save_data = {'sample_captions': sample_captions,
        'gt_captions': gt_captions}
    with open('captioning_extra_credit.pkl', 'wb') as fout:
        pickle.dump(save_data, fout)

# %%
np.random.seed(231)

small_data = load_coco_data(max_train=70000)

best_model = CaptioningRNN(
          cell_type='lstm',
          word_to_idx=small_data['word_to_idx'],
          input_dim=small_data['train_features'].shape[1],
          hidden_dim=256,
          wordvec_dim=256,
          dtype=np.float32,
        )

small_lstm_solver = CaptioningSolver(best_model, small_data,
           update_rule='adam',
           num_epochs=15,
           batch_size=128,
           optim_config={
            'learning_rate': 5e-4,
           },
           lr_decay=0.99,
           verbose=True, print_every=50,
         )

small_lstm_solver.train(evaluate_model)

# Plot the training losses
plt.plot(small_lstm_solver.loss_history)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training loss history')
plt.show()

print(evaluate_model(best_model))
#save_model_prediction(best_model)
# Out:
# (Iteration 1 / 8190) loss: 76.749604
# Average BLEU score for train: 0.020377
# Average BLEU score for val: 0.021636
# (Iteration 51 / 8190) loss: 56.686143
# Average BLEU score for train: 0.106595
# Average BLEU score for val: 0.108619
# (Iteration 101 / 8190) loss: 49.667484
# Average BLEU score for train: 0.140130
# Average BLEU score for val: 0.139154
# (Iteration 151 / 8190) loss: 47.384970
# Average BLEU score for train: 0.020286
# Average BLEU score for val: 0.024494
# (Iteration 201 / 8190) loss: 43.651464
# Average BLEU score for train: 0.133547
# Average BLEU score for val: 0.127755
# (Iteration 251 / 8190) loss: 41.776558
# Average BLEU score for train: 0.144771
# Average BLEU score for val: 0.152108
# (Iteration 301 / 8190) loss: 39.868459
# Average BLEU score for train: 0.101850
# Average BLEU score for val: 0.097236
# (Iteration 351 / 8190) loss: 39.731970
# Average BLEU score for train: 0.161873
# Average BLEU score for val: 0.165340
# (Iteration 401 / 8190) loss: 37.942421
# Average BLEU score for train: 0.140142
# Average BLEU score for val: 0.137990
# (Iteration 451 / 8190) loss: 36.937008
# Average BLEU score for train: 0.145182
# Average BLEU score for val: 0.143311
# (Iteration 501 / 8190) loss: 36.416062
# Average BLEU score for train: 0.184186
# Average BLEU score for val: 0.175517
# (Iteration 551 / 8190) loss: 37.135033
# Average BLEU score for train: 0.171895
# Average BLEU score for val: 0.160185
# (Iteration 601 / 8190) loss: 36.008741
# Average BLEU score for train: 0.176798
# Average BLEU score for val: 0.165094
# (Iteration 651 / 8190) loss: 32.759782
# Average BLEU score for train: 0.188953
# Average BLEU score for val: 0.176212
# (Iteration 701 / 8190) loss: 32.109351
# Average BLEU score for train: 0.177190
# Average BLEU score for val: 0.168200
# (Iteration 751 / 8190) loss: 32.107404
# Average BLEU score for train: 0.220374
# Average BLEU score for val: 0.221317
# (Iteration 801 / 8190) loss: 33.209575
# Average BLEU score for train: 0.213012
# Average BLEU score for val: 0.205427
# (Iteration 851 / 8190) loss: 30.852452
# Average BLEU score for train: 0.206247
# Average BLEU score for val: 0.203660
# (Iteration 901 / 8190) loss: 30.470513
# Average BLEU score for train: 0.207762
# Average BLEU score for val: 0.199420
# (Iteration 951 / 8190) loss: 32.660202
# Average BLEU score for train: 0.240431
# Average BLEU score for val: 0.238579
# (Iteration 1001 / 8190) loss: 31.108633
# Average BLEU score for train: 0.249316
# Average BLEU score for val: 0.240191
# (Iteration 1051 / 8190) loss: 32.535194
# Average BLEU score for train: 0.239248
# Average BLEU score for val: 0.235502
# (Iteration 1101 / 8190) loss: 32.070162
# Average BLEU score for train: 0.249171
# Average BLEU score for val: 0.240148
# (Iteration 1151 / 8190) loss: 31.045147
# Average BLEU score for train: 0.267610
# Average BLEU score for val: 0.256834
# (Iteration 1201 / 8190) loss: 30.742269
# Average BLEU score for train: 0.268315
# Average BLEU score for val: 0.263427
# (Iteration 1251 / 8190) loss: 30.797207
# Average BLEU score for train: 0.246392
# Average BLEU score for val: 0.245850
# (Iteration 1301 / 8190) loss: 29.576877
# Average BLEU score for train: 0.249956
# Average BLEU score for val: 0.244983
# (Iteration 1351 / 8190) loss: 31.346810
# Average BLEU score for train: 0.267100
# Average BLEU score for val: 0.268925
# (Iteration 1401 / 8190) loss: 30.104282
# Average BLEU score for train: 0.247933
# Average BLEU score for val: 0.242455
# (Iteration 1451 / 8190) loss: 28.478365
# Average BLEU score for train: 0.266610
# Average BLEU score for val: 0.255992
# (Iteration 1501 / 8190) loss: 29.567850
# Average BLEU score for train: 0.252588
# Average BLEU score for val: 0.250243
# (Iteration 1551 / 8190) loss: 28.981351
# Average BLEU score for train: 0.260597
# Average BLEU score for val: 0.256571
# (Iteration 1601 / 8190) loss: 29.574452
# Average BLEU score for train: 0.249862
# Average BLEU score for val: 0.244489
# (Iteration 1651 / 8190) loss: 29.511421
# Average BLEU score for train: 0.252979
# Average BLEU score for val: 0.252085
# (Iteration 1701 / 8190) loss: 28.086421
# Average BLEU score for train: 0.280503
# Average BLEU score for val: 0.271116
# (Iteration 1751 / 8190) loss: 27.761534
# Average BLEU score for train: 0.272797
# Average BLEU score for val: 0.261067
# (Iteration 1801 / 8190) loss: 27.525484
# Average BLEU score for train: 0.262514
# Average BLEU score for val: 0.268483
# (Iteration 1851 / 8190) loss: 29.471996
# Average BLEU score for train: 0.260843
# Average BLEU score for val: 0.248896
# (Iteration 1901 / 8190) loss: 29.921664
# Average BLEU score for train: 0.278933
# Average BLEU score for val: 0.268383
# (Iteration 1951 / 8190) loss: 28.069956
# Average BLEU score for train: 0.281993
# Average BLEU score for val: 0.266120
# (Iteration 2001 / 8190) loss: 28.967255
# Average BLEU score for train: 0.266482
# Average BLEU score for val: 0.257281
# (Iteration 2051 / 8190) loss: 27.807683
# Average BLEU score for train: 0.273031
# Average BLEU score for val: 0.269732
# (Iteration 2101 / 8190) loss: 28.218334
# Average BLEU score for train: 0.273676
# Average BLEU score for val: 0.273863
# (Iteration 2151 / 8190) loss: 27.002634
# Average BLEU score for train: 0.275612
# Average BLEU score for val: 0.262734
# (Iteration 2201 / 8190) loss: 26.662069
# Average BLEU score for train: 0.264189
# Average BLEU score for val: 0.261355
# (Iteration 2251 / 8190) loss: 26.489342
# Average BLEU score for train: 0.271792
# Average BLEU score for val: 0.259776
# (Iteration 2301 / 8190) loss: 28.092628
# Average BLEU score for train: 0.262110
# Average BLEU score for val: 0.266393
# (Iteration 2351 / 8190) loss: 27.452309
# Average BLEU score for train: 0.260317
# Average BLEU score for val: 0.250227
# (Iteration 2401 / 8190) loss: 27.469648
# Average BLEU score for train: 0.280266
# Average BLEU score for val: 0.281689
# (Iteration 2451 / 8190) loss: 27.703203
# Average BLEU score for train: 0.267810
# Average BLEU score for val: 0.267697
# (Iteration 2501 / 8190) loss: 26.956032
# Average BLEU score for train: 0.279860
# Average BLEU score for val: 0.272893
# (Iteration 2551 / 8190) loss: 28.518236
# Average BLEU score for train: 0.282991
# Average BLEU score for val: 0.268537
# (Iteration 2601 / 8190) loss: 27.760454
# Average BLEU score for train: 0.286041
# Average BLEU score for val: 0.272826
# (Iteration 2651 / 8190) loss: 27.220233
# Average BLEU score for train: 0.285427
# Average BLEU score for val: 0.276764
# (Iteration 2701 / 8190) loss: 27.298261
# Average BLEU score for train: 0.272092
# Average BLEU score for val: 0.262927
# (Iteration 2751 / 8190) loss: 27.019430
# Average BLEU score for train: 0.289656
# Average BLEU score for val: 0.276484
# (Iteration 2801 / 8190) loss: 26.645569
# Average BLEU score for train: 0.300249
# Average BLEU score for val: 0.289487
# (Iteration 2851 / 8190) loss: 26.069258
# Average BLEU score for train: 0.272417
# Average BLEU score for val: 0.273125
# (Iteration 2901 / 8190) loss: 26.909624
# Average BLEU score for train: 0.283306
# Average BLEU score for val: 0.281219
# (Iteration 2951 / 8190) loss: 26.858895
# Average BLEU score for train: 0.289316
# Average BLEU score for val: 0.271088
# (Iteration 3001 / 8190) loss: 26.077886
# Average BLEU score for train: 0.270515
# Average BLEU score for val: 0.276480
# (Iteration 3051 / 8190) loss: 26.490675
# Average BLEU score for train: 0.278071
# Average BLEU score for val: 0.269128
# (Iteration 3101 / 8190) loss: 27.045328
# Average BLEU score for train: 0.279708
# Average BLEU score for val: 0.262269
# (Iteration 3151 / 8190) loss: 26.488577
# Average BLEU score for train: 0.281010
# Average BLEU score for val: 0.280165
# (Iteration 3201 / 8190) loss: 25.390798
# Average BLEU score for train: 0.283090
# Average BLEU score for val: 0.274744
# (Iteration 3251 / 8190) loss: 25.565392
# Average BLEU score for train: 0.277962
# Average BLEU score for val: 0.265493
# (Iteration 3301 / 8190) loss: 28.108780
# Average BLEU score for train: 0.294643
# Average BLEU score for val: 0.277332
# (Iteration 3351 / 8190) loss: 25.533609
# Average BLEU score for train: 0.286383
# Average BLEU score for val: 0.262821
# (Iteration 3401 / 8190) loss: 27.316599
# Average BLEU score for train: 0.288373
# Average BLEU score for val: 0.276075
# (Iteration 3451 / 8190) loss: 25.994054
# Average BLEU score for train: 0.292782
# Average BLEU score for val: 0.277373
# (Iteration 3501 / 8190) loss: 26.025799
# Average BLEU score for train: 0.282794
# Average BLEU score for val: 0.279890
# (Iteration 3551 / 8190) loss: 27.248449
# Average BLEU score for train: 0.275592
# Average BLEU score for val: 0.274674
# (Iteration 3601 / 8190) loss: 27.408609
# Average BLEU score for train: 0.295325
# Average BLEU score for val: 0.279047
# (Iteration 3651 / 8190) loss: 26.230994
# Average BLEU score for train: 0.280947
# Average BLEU score for val: 0.260996
# (Iteration 3701 / 8190) loss: 25.740181
# Average BLEU score for train: 0.280947
# Average BLEU score for val: 0.275310
# (Iteration 3751 / 8190) loss: 24.400847
# Average BLEU score for train: 0.290613
# Average BLEU score for val: 0.272683
# (Iteration 3801 / 8190) loss: 26.374526
# Average BLEU score for train: 0.292490
# Average BLEU score for val: 0.270938
# (Iteration 3851 / 8190) loss: 25.439729
# Average BLEU score for train: 0.273500
# Average BLEU score for val: 0.277149
# (Iteration 3901 / 8190) loss: 24.760327
# Average BLEU score for train: 0.288883
# Average BLEU score for val: 0.288479
# (Iteration 3951 / 8190) loss: 26.465458
# Average BLEU score for train: 0.276102
# Average BLEU score for val: 0.268048
# (Iteration 4001 / 8190) loss: 24.989852
# Average BLEU score for train: 0.291138
# Average BLEU score for val: 0.279442
# (Iteration 4051 / 8190) loss: 25.098749
# Average BLEU score for train: 0.294912
# Average BLEU score for val: 0.285490
# (Iteration 4101 / 8190) loss: 25.589493
# Average BLEU score for train: 0.287507
# Average BLEU score for val: 0.279201
# (Iteration 4151 / 8190) loss: 27.278532
# Average BLEU score for train: 0.288990
# Average BLEU score for val: 0.261497
# (Iteration 4201 / 8190) loss: 24.271672
# Average BLEU score for train: 0.289293
# Average BLEU score for val: 0.276326
# (Iteration 4251 / 8190) loss: 25.149486
# Average BLEU score for train: 0.284671
# Average BLEU score for val: 0.285388
# (Iteration 4301 / 8190) loss: 26.523178
# Average BLEU score for train: 0.280257
# Average BLEU score for val: 0.274718
# (Iteration 4351 / 8190) loss: 24.777620
# Average BLEU score for train: 0.302846
# Average BLEU score for val: 0.284238
# (Iteration 4401 / 8190) loss: 25.854806
# Average BLEU score for train: 0.280510
# Average BLEU score for val: 0.282171
# (Iteration 4451 / 8190) loss: 25.259602
# Average BLEU score for train: 0.291912
# Average BLEU score for val: 0.284954
# (Iteration 4501 / 8190) loss: 25.427538
# Average BLEU score for train: 0.299068
# Average BLEU score for val: 0.271030
# (Iteration 4551 / 8190) loss: 25.843807
# Average BLEU score for train: 0.286277
# Average BLEU score for val: 0.287051
# (Iteration 4601 / 8190) loss: 24.200156
# Average BLEU score for train: 0.298940
# Average BLEU score for val: 0.276993
# (Iteration 4651 / 8190) loss: 22.767710
# Average BLEU score for train: 0.284227
# Average BLEU score for val: 0.268113
# (Iteration 4701 / 8190) loss: 26.035454
# Average BLEU score for train: 0.292009
# Average BLEU score for val: 0.260246
# (Iteration 4751 / 8190) loss: 23.937144
# Average BLEU score for train: 0.287510
# Average BLEU score for val: 0.294840
# (Iteration 4801 / 8190) loss: 25.598618
# Average BLEU score for train: 0.289836
# Average BLEU score for val: 0.284420
# (Iteration 4851 / 8190) loss: 23.825328
# Average BLEU score for train: 0.290068
# Average BLEU score for val: 0.273919
# (Iteration 4901 / 8190) loss: 26.160381
# Average BLEU score for train: 0.294600
# Average BLEU score for val: 0.274134
# (Iteration 4951 / 8190) loss: 24.324592
# Average BLEU score for train: 0.302694
# Average BLEU score for val: 0.282840
# (Iteration 5001 / 8190) loss: 25.124888
# Average BLEU score for train: 0.308899
# Average BLEU score for val: 0.287425
# (Iteration 5051 / 8190) loss: 23.549312
# Average BLEU score for train: 0.284987
# Average BLEU score for val: 0.278674
# (Iteration 5101 / 8190) loss: 23.488902
# Average BLEU score for train: 0.308520
# Average BLEU score for val: 0.286800
# (Iteration 5151 / 8190) loss: 26.272083
# Average BLEU score for train: 0.296516
# Average BLEU score for val: 0.276354
# (Iteration 5201 / 8190) loss: 23.770408
# Average BLEU score for train: 0.305660
# Average BLEU score for val: 0.273606
# (Iteration 5251 / 8190) loss: 23.296529
# Average BLEU score for train: 0.303618
# Average BLEU score for val: 0.292217
# (Iteration 5301 / 8190) loss: 25.269017
# Average BLEU score for train: 0.282835
# Average BLEU score for val: 0.273969
# (Iteration 5351 / 8190) loss: 24.193650
# Average BLEU score for train: 0.290905
# Average BLEU score for val: 0.288363
# (Iteration 5401 / 8190) loss: 23.901897
# Average BLEU score for train: 0.288171
# Average BLEU score for val: 0.281800
# (Iteration 5451 / 8190) loss: 23.362016
# Average BLEU score for train: 0.288477
# Average BLEU score for val: 0.281481
# (Iteration 5501 / 8190) loss: 23.399423
# Average BLEU score for train: 0.286022
# Average BLEU score for val: 0.271664
# (Iteration 5551 / 8190) loss: 24.350436
# Average BLEU score for train: 0.296289
# Average BLEU score for val: 0.286370
# (Iteration 5601 / 8190) loss: 24.549788
# Average BLEU score for train: 0.295364
# Average BLEU score for val: 0.287408
# (Iteration 5651 / 8190) loss: 24.435917
# Average BLEU score for train: 0.299114
# Average BLEU score for val: 0.291877
# (Iteration 5701 / 8190) loss: 23.957361
# Average BLEU score for train: 0.289838
# Average BLEU score for val: 0.276708
# (Iteration 5751 / 8190) loss: 23.455186
# Average BLEU score for train: 0.294362
# Average BLEU score for val: 0.291751
# (Iteration 5801 / 8190) loss: 25.646905
# Average BLEU score for train: 0.286909
# Average BLEU score for val: 0.281692
# (Iteration 5851 / 8190) loss: 23.988724
# Average BLEU score for train: 0.297267
# Average BLEU score for val: 0.283279
# (Iteration 5901 / 8190) loss: 24.100935
# Average BLEU score for train: 0.293955
# Average BLEU score for val: 0.286918
# (Iteration 5951 / 8190) loss: 24.739500
# Average BLEU score for train: 0.298812
# Average BLEU score for val: 0.288284
# (Iteration 6001 / 8190) loss: 24.054113
# Average BLEU score for train: 0.287400
# Average BLEU score for val: 0.276295
# (Iteration 6051 / 8190) loss: 25.480201
# Average BLEU score for train: 0.297342
# Average BLEU score for val: 0.292528
# (Iteration 6101 / 8190) loss: 23.674821
# Average BLEU score for train: 0.303778
# Average BLEU score for val: 0.282136
# (Iteration 6151 / 8190) loss: 24.804503
# Average BLEU score for train: 0.286963
# Average BLEU score for val: 0.287700
# (Iteration 6201 / 8190) loss: 23.460160
# Average BLEU score for train: 0.298423
# Average BLEU score for val: 0.289484
# (Iteration 6251 / 8190) loss: 23.731087
# Average BLEU score for train: 0.297152
# Average BLEU score for val: 0.293096
# (Iteration 6301 / 8190) loss: 23.492124
# Average BLEU score for train: 0.295888
# Average BLEU score for val: 0.278455
# (Iteration 6351 / 8190) loss: 22.961872
# Average BLEU score for train: 0.292981
# Average BLEU score for val: 0.286440
# (Iteration 6401 / 8190) loss: 24.157193
# Average BLEU score for train: 0.291661
# Average BLEU score for val: 0.277090
# (Iteration 6451 / 8190) loss: 24.085658
# Average BLEU score for train: 0.296199
# Average BLEU score for val: 0.271590
# (Iteration 6501 / 8190) loss: 22.144410
# Average BLEU score for train: 0.297156
# Average BLEU score for val: 0.285127
# (Iteration 6551 / 8190) loss: 23.726049
# Average BLEU score for train: 0.297447
# Average BLEU score for val: 0.289222
# (Iteration 6601 / 8190) loss: 24.879007
# Average BLEU score for train: 0.298974
# Average BLEU score for val: 0.283279
# (Iteration 6651 / 8190) loss: 23.156971
# Average BLEU score for train: 0.302383
# Average BLEU score for val: 0.289673
# (Iteration 6701 / 8190) loss: 23.376785
# Average BLEU score for train: 0.294037
# Average BLEU score for val: 0.273407
# (Iteration 6751 / 8190) loss: 23.431675
# Average BLEU score for train: 0.303542
# Average BLEU score for val: 0.276034
# (Iteration 6801 / 8190) loss: 23.140295
# Average BLEU score for train: 0.299437
# Average BLEU score for val: 0.277455
# (Iteration 6851 / 8190) loss: 23.920827
# Average BLEU score for train: 0.288132
# Average BLEU score for val: 0.289491
# (Iteration 6901 / 8190) loss: 24.139582
# Average BLEU score for train: 0.293709
# Average BLEU score for val: 0.277462
# (Iteration 6951 / 8190) loss: 22.307500
# Average BLEU score for train: 0.294553
# Average BLEU score for val: 0.291229
# (Iteration 7001 / 8190) loss: 24.271523
# Average BLEU score for train: 0.288456
# Average BLEU score for val: 0.284917
# (Iteration 7051 / 8190) loss: 24.204840
# Average BLEU score for train: 0.291184
# Average BLEU score for val: 0.283245
# (Iteration 7101 / 8190) loss: 22.627145
# Average BLEU score for train: 0.294606
# Average BLEU score for val: 0.284731
# (Iteration 7151 / 8190) loss: 23.122058
# Average BLEU score for train: 0.300079
# Average BLEU score for val: 0.286597
# (Iteration 7201 / 8190) loss: 22.935248
# Average BLEU score for train: 0.294165
# Average BLEU score for val: 0.287181
# (Iteration 7251 / 8190) loss: 23.598931
# Average BLEU score for train: 0.295811
# Average BLEU score for val: 0.281262
# (Iteration 7301 / 8190) loss: 23.176514
# Average BLEU score for train: 0.304735
# Average BLEU score for val: 0.279322
# (Iteration 7351 / 8190) loss: 23.148556
# Average BLEU score for train: 0.290580
# Average BLEU score for val: 0.283926
# (Iteration 7401 / 8190) loss: 21.862299
# Average BLEU score for train: 0.293485
# Average BLEU score for val: 0.281256
# (Iteration 7451 / 8190) loss: 22.858996
# Average BLEU score for train: 0.294941
# Average BLEU score for val: 0.276537
# (Iteration 7501 / 8190) loss: 24.234108
# Average BLEU score for train: 0.305276
# Average BLEU score for val: 0.274451
# (Iteration 7551 / 8190) loss: 21.608294
# Average BLEU score for train: 0.302625
# Average BLEU score for val: 0.278393
# (Iteration 7601 / 8190) loss: 22.452782
# Average BLEU score for train: 0.307779
# Average BLEU score for val: 0.293498
# (Iteration 7651 / 8190) loss: 22.748887
# Average BLEU score for train: 0.311081
# Average BLEU score for val: 0.287597
# (Iteration 7701 / 8190) loss: 23.271735
# Average BLEU score for train: 0.310056
# Average BLEU score for val: 0.280675
# (Iteration 7751 / 8190) loss: 21.462070
# Average BLEU score for train: 0.313661
# Average BLEU score for val: 0.288763
# (Iteration 7801 / 8190) loss: 21.372279
# Average BLEU score for train: 0.313562
# Average BLEU score for val: 0.280933
# (Iteration 7851 / 8190) loss: 22.127337
# Average BLEU score for train: 0.288255
# Average BLEU score for val: 0.278358
# (Iteration 7901 / 8190) loss: 22.475952
# Average BLEU score for train: 0.313468
# Average BLEU score for val: 0.283534
# (Iteration 7951 / 8190) loss: 22.128392
# Average BLEU score for train: 0.308497
# Average BLEU score for val: 0.284131
# (Iteration 8001 / 8190) loss: 22.146253
# Average BLEU score for train: 0.291718
# Average BLEU score for val: 0.285662
# (Iteration 8051 / 8190) loss: 24.531992
# Average BLEU score for train: 0.298158
# Average BLEU score for val: 0.284117
# (Iteration 8101 / 8190) loss: 23.151464
# Average BLEU score for train: 0.294101
# Average BLEU score for val: 0.282626
# (Iteration 8151 / 8190) loss: 22.058768
# Average BLEU score for train: 0.302127
# Average BLEU score for val: 0.282708
# Average BLEU score for train: 0.297370
# Average BLEU score for val: 0.277431
# None

# %%
sample_coco_minibatch(data = fulldata)[1].shape
# Out:
# (100, 512)

# %%
#best wordvec dim:256-512 
#epochs:
#0.279573
